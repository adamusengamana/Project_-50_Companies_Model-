# %% [markdown]
# # **Multiple Regression Models**

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
print("Models loaded successfully.......")
# Out:
# Models loaded successfully.......

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/INTERNSHIP 2024/50_Startups Dataset.csv')
df.head(10)
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94
# 5  131876.90        99814.71        362861.36  156991.12
# 6  134615.46       147198.87        127716.82  156122.51
# 7  130298.13       145530.06        323876.68  155752.60
# 8  120542.52       148718.95        311613.29  152211.77
# 9  123334.88       108679.17        304981.62  149759.96

# %%
# !git  config --global user.name "Ada"
# !git  config --global user.email "adamusengamana@gmail.com"
# !git  config --global user.password "musengamana01."

# %%
token="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"
# !git clone https://{token}@github.com/adamusengamana/Project_-50_Companies_Model-.git
# Out:
# Cloning into 'Project_-50_Companies_Model-'...
# warning: You appear to have cloned an empty repository.

# %%
# %cd Project_-50_Companies_Model-
# Out:
# /content/Project_-50_Companies_Model-

# %%
# !cp  /content/drive/MyDrive/Colab\ Notebooks/Project\ \[50\ Companies Model\].ipynb .
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab Notebooks/Project [50 Companies': No such file or directory
# cp: cannot stat 'Model].ipynb': No such file or directory

# %%
# !git add .

# %%
# !git commit -m "Committed first files"
# Out:
# [main (root-commit) 1b91c9a] Committed first files
#  4 files changed, 51 insertions(+)
#  create mode 100644 50_Startups Dataset.csv
#  create mode 100644 EDL STANDING INSTRUCTIONS TO SUBMIT THE PROJECT.pdf
#  create mode 100644 Guide lines.pdf
#  create mode 100644 PROJECT[DATA SCIENCE].pdf

# %%
# !git remote -v
# Out:
# origin	https://github.com/adamusengamana/Project_-50_Companies_Model-.git (fetch)
# origin	https://github.com/adamusengamana/Project_-50_Companies_Model-.git (push)

# %%
# !git push  origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git branch
# Out:
# * main
